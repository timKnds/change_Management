# %%
import pandas as pd

# %%
df= pd.read_csv('fahrzeugsysteme_komponenten.csv', sep=';')

# %%
df
# Out:
#             Ebene1                   Ebene2                       Ebene3  \
# 0       Fahrsystem           Antriebssystem     Vorderachsantriebssystem
# 1       Fahrsystem           Antriebssystem     Vorderachsantriebssystem
# 2       Fahrsystem           Antriebssystem     Vorderachsantriebssystem
# 3       Fahrsystem           Antriebssystem     Vorderachsantriebssystem
# 4       Fahrsystem           Antriebssystem     Vorderachsantriebssystem
# ..             ...                      ...                          ...
# 120  Energiesystem  Energiemanagementsystem  Effizienzoptimierungssystem
# 121  Energiesystem  Energiemanagementsystem   Lade-Entladeplanungssystem
# 122  Energiesystem  Energiemanagementsystem   Lade-Entladeplanungssystem
# 123  Energiesystem  Energiemanagementsystem  Energiepriorisierungssystem
# 124  Energiesystem  Energiemanagementsystem  Energiepriorisierungssystem
#
#                Komponente           ID  Einkaufspreis_EUR
# ...
